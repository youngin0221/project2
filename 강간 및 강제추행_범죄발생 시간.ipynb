# %% [markdown]
# # 범죄발생 시간 (2011~2020)
# https://kosis.kr/statHtml/statHtml.do?orgId=132&tblId=DT_13204_3101

# %%
import folium
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import branca.colormap as cm
import matplotlib.pyplot as plt 
import matplotlib.ticker as mticker
# %matplotlib inline

plt.rcParams["font.family"] = 'Malgun Gothic'
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('강간 및 강제추행_범죄발생 시간_수정.csv')
df
# Out:
#             시간  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0  00:00~02:59  2614  2278  2434  2188  2195  2581  2826  2604  2623  2375
# 1  03:00~05:59  2761  2675  2725  2446  2453  2613  3006  2907  2963  2472
# 2  06:00~08:59  1838  1654  1777  1674  1595  1704  1987  1737  1779  1314
# 3  09:00~11:59   958  1073  1256  1211  1285  1362  1730  1589  1544  1507
# 4  12:00~14:59   748  1142  1310  1322  1352  1460  1744  1702  1705  1669
# 5  15:00~17:59  1349  1423  1711  1736  1716  1888  2134  2074  2109  1921
# 6  18:00~20:59  1976  1799  2183  2182  2233  2578  2869  2679  2710  2522
# 7  21:00~23:59  3110  3248  3626  3367  3301  3762  3945  3846  3749  3734

# %%
df['총'] = df.sum(axis=1)
df
# Out:
#             시간  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  \
# 0  00:00~02:59  2614  2278  2434  2188  2195  2581  2826  2604  2623  2375
# 1  03:00~05:59  2761  2675  2725  2446  2453  2613  3006  2907  2963  2472
# 2  06:00~08:59  1838  1654  1777  1674  1595  1704  1987  1737  1779  1314
# 3  09:00~11:59   958  1073  1256  1211  1285  1362  1730  1589  1544  1507
# 4  12:00~14:59   748  1142  1310  1322  1352  1460  1744  1702  1705  1669
# 5  15:00~17:59  1349  1423  1711  1736  1716  1888  2134  2074  2109  1921
# 6  18:00~20:59  1976  1799  2183  2182  2233  2578  2869  2679  2710  2522
# 7  21:00~23:59  3110  3248  3626  3367  3301  3762  3945  3846  3749  3734
#
#        총
# 0  24718
# 1  27021
# 2  17059
# 3  13515
# 4  14154
# 5  18061
# 6  23731
# 7  35688

# %% [markdown]
# ## bar

# %%
df.plot(x ='시간',y='2011', kind='bar', figsize=(15,8), fontsize = 13, rot=0)
plt.title('범죄 발생 시간 - 2011년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.show()

# %%
df.plot(x ='시간',y='2012', kind='bar', figsize=(15,8), fontsize = 13, rot=0)
plt.title('범죄 발생 시간 - 2012년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.show()

# %%
df.plot(x ='시간',y='2013', kind='bar', figsize=(15,8), fontsize = 13, rot=0)
plt.title('범죄 발생 시간 - 2013년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.show()

# %%
df.plot(x ='시간',y='2014', kind='bar', figsize=(15,8), fontsize = 13, rot=0)
plt.title('범죄 발생 시간 - 2014년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.show()

# %%
df.plot(x ='시간',y='2015', kind='bar', figsize=(15,8), fontsize = 13, rot=0)
plt.title('범죄 발생 시간 - 2015년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.show()

# %%
df.plot(x ='시간',y='2016', kind='bar', figsize=(15,8), fontsize = 13, rot=0)
plt.title('범죄 발생 시간 - 2016년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.show()

# %%
df.plot(x ='시간',y='2017', kind='bar', figsize=(15,8), fontsize = 13, rot=0)
plt.title('범죄 발생 시간 - 2017년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.show()

# %%
df.plot(x ='시간',y='2018', kind='bar', figsize=(15,8), fontsize = 13, rot=0)
plt.title('범죄 발생 시간 - 2018년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.show()

# %%
df.plot(x ='시간',y='2019', kind='bar', figsize=(15,8), fontsize = 13, rot=0, color = ['#0B69A3'])
plt.title('범죄 발생 시간 - 2019년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.savefig('./강간 및 강제추행 발생 시간 (2019년).png')

# %%
df.plot(x ='시간',y='2020', kind='bar', figsize=(15,8), fontsize = 13, rot=0)
plt.title('범죄 발생 시간 - 2020년 (단위 : 건)', fontsize=17) 
plt.xlabel(None)
plt.show()

# %%
df.plot(x="시간", y=["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"], kind="bar",figsize=(15,8), rot=0, fontsize=15)
plt.title('범죄 발생 시간 (단위 : 건)', fontsize=17)
plt.legend(loc='upper left')
plt.xlabel(None)
plt.show()

# %%
df.plot(x="시간", y='총', kind="bar",figsize=(15,8), rot=0, fontsize=15)
plt.title('범죄 발생 시간 (단위 : 건)', fontsize=17)
plt.legend(loc='upper left')
plt.xlabel(None)
plt.show()

# %%
df = pd.read_csv('강간 및 강제추행_범죄발생 시간_수정 - 복사본.csv')
df
# Out:
#             시간  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0  06:00~08:59  1838  1654  1777  1674  1595  1704  1987  1737  1779  1314
# 1  09:00~11:59   958  1073  1256  1211  1285  1362  1730  1589  1544  1507
# 2  12:00~14:59   748  1142  1310  1322  1352  1460  1744  1702  1705  1669
# 3  15:00~17:59  1349  1423  1711  1736  1716  1888  2134  2074  2109  1921
# 4  18:00~20:59  1976  1799  2183  2182  2233  2578  2869  2679  2710  2522
# 5  21:00~23:59  3110  3248  3626  3367  3301  3762  3945  3846  3749  3734
# 6  00:00~02:59  2614  2278  2434  2188  2195  2581  2826  2604  2623  2375
# 7  03:00~05:59  2761  2675  2725  2446  2453  2613  3006  2907  2963  2472

# %%
df.plot(x ='시간',y='2019', kind='bar', figsize=(15,8), fontsize = 16, rot=0, color = ['#0B69A3'])
plt.title('범죄 발생 시간 - 2019년 (단위 : 건)', fontsize=18) 
plt.xlabel(None)
plt.yticks([0,1000,2000,3000,4000], ['0', '1,000', '2,000', '3,000', '4,000'])
plt.savefig('./강간 및 강제추행 발생 시간 (2019년) - 6시부터.png')
